# %%
import pandas as pd
print("$>$")
# Out:
# $>$

# %%
df = pd.read_csv("D:/University/National_Universities_Rankings (1).csv")
df.head()
# Out:
#    index                   Name       Location  Rank  \
# 0      0   Princeton University  Princeton, NJ     1
# 1      1     Harvard University  Cambridge, MA     2
# 2      2  University of Chicago    Chicago, IL     3
# 3      3        Yale University  New Haven, CT     3
# 4      4    Columbia University   New York, NY     5
#
#                                          Description Tuition and fees  \
# 0  Princeton, the fourth-oldest college in the Un...         $45,320
# 1  Harvard is located in Cambridge, Massachusetts...         $47,074
# 2  The University of Chicago, situated in Chicago...         $52,491
# 3  Yale University, located in New Haven, Connect...         $49,480
# 4  Columbia University, located in Manhattan's Mo...         $55,056
#
#   In-state Undergrad Enrollment
# 0      NaN                5,402
# 1      NaN                6,699
# 2      NaN                5,844
# 3      NaN                5,532
# 4      NaN                6,102

# %%
df["State"] = df.Location.str[-2:]
df["City"] = df.Location.str[:-4]
df.head()
# Out:
#    index                   Name       Location  Rank  \
# 0      0   Princeton University  Princeton, NJ     1
# 1      1     Harvard University  Cambridge, MA     2
# 2      2  University of Chicago    Chicago, IL     3
# 3      3        Yale University  New Haven, CT     3
# 4      4    Columbia University   New York, NY     5
#
#                                          Description Tuition and fees  \
# 0  Princeton, the fourth-oldest college in the Un...         $45,320
# 1  Harvard is located in Cambridge, Massachusetts...         $47,074
# 2  The University of Chicago, situated in Chicago...         $52,491
# 3  Yale University, located in New Haven, Connect...         $49,480
# 4  Columbia University, located in Manhattan's Mo...         $55,056
#
#   In-state Undergrad Enrollment State       City
# 0      NaN                5,402    NJ  Princeton
# 1      NaN                6,699    MA  Cambridge
# 2      NaN                5,844    IL    Chicago
# ...

# %%
df.groupby(["State","City"])["Name"].apply(list)
# Out:
# State  City
# AK     Fairbanks                     [University of Alaska--Fairbanks]
# AL     Auburn                                      [Auburn University]
#        Birmingham                  [University of Alabama--Birmingham]
#        Huntsville                  [University of Alabama--Huntsville]
#        Tuscaloosa                              [University of Alabama]
#                                            ...
# WA     Seattle       [University of Washington, Seattle Pacific Uni...
# WI     Madison       [University of Wisconsin--Madison, Edgewood Co...
#        Milwaukee                                [Marquette University]
# WV     Morgantown                           [West Virginia University]
# WY     Laramie                                 [University of Wyoming]
# Name: Name, Length: 192, dtype: object

# %%
x = df[df["Rank"]<50]

x.groupby(["State","Rank"])["Name"].apply(list)
# Out:
# State  Rank
# CA     5                                   [Stanford University]
#        12                   [California Institute of Technology]
#        20                   [University of California--Berkeley]
#        23                    [University of Southern California]
#        24                [University of California--Los Angeles]
#        37              [University of California--Santa Barbara]
#        39                     [University of California--Irvine]
#        44      [University of California--Davis, University o...
# CT     3                                       [Yale University]
# DC     20                                [Georgetown University]
# FL     44                                  [University of Miami]
# GA     20                                     [Emory University]
#        34                      [Georgia Institute of Technology]
# IL     3                                 [University of Chicago]
# ...

# %%
df["Margin"]= df["Tuition and fees"].str.replace('$',"",regex = True).replace(",","",regex=True).apply(int)-df[df["In-state"].notnull()]["In-state"].str.replace('$',"",regex = True).replace(",","",regex=True).apply(int)

df[df["Margin"]<=5000]["Name"].count()
# Out:
# 2

# %%
df[df["Rank"]>120][df["Rank"]<170][df["Tuition and fees"].str.replace('$',"",regex = True).replace(",","",regex=True).apply(int)>15000]
# Out:
# C:\Users\exam2\AppData\Local\Temp/ipykernel_6872/2087880593.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df["Rank"]>120][df["Rank"]<170][df["Tuition and fees"].str.replace('$',"",regex = True).replace(",","",regex=True).apply(int)>15000]
#      index                                         Name          Location  \
# 123    123           The Catholic University of America    Washington, DC
# 124    124                            DePaul University       Chicago, IL
# 125    125                          Duquesne University    Pittsburgh, PA
# 126    126                            Howard University    Washington, DC
# 127    127                        University of Arizona        Tucson, AZ
# 128    128              Arizona State University--Tempe         Tempe, AZ
# 129    129                          Clarkson University       Potsdam, NY
# 130    130                    Colorado State University  Fort Collins, CO
# ...

# %%
df[df["In-state"].notnull()][df["Tuition and fees"].notnull()]["Name"].count()
# Out:
# C:\Users\exam2\AppData\Local\Temp/ipykernel_6872/1294104482.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df["In-state"].notnull()][df["Tuition and fees"].notnull()]["Name"].count()
# 133

# %%
df.groupby("Name").head()
# Out:
#      index                                      Name             Location  \
# 0        0                      Princeton University        Princeton, NJ
# 1        1                        Harvard University        Cambridge, MA
# 2        2                     University of Chicago          Chicago, IL
# 3        3                           Yale University        New Haven, CT
# 4        4                       Columbia University         New York, NY
# ..     ...                                       ...                  ...
# 226    226    University of Massachusetts--Dartmouth  North Dartmouth, MA
# 227    227         University of Missouri--St. Louis        St. Louis, MO
# 228    228  University of North Carolina--Greensboro       Greensboro, NC
# 229    229        University of Southern Mississippi      Hattiesburg, MS
# 230    230                     Utah State University            Logan, UT
#
#      Rank                                        Description Tuition and fees  \
# ...

# %%
#9.	Mention the states where out-of state fee is more than in-state students

x = df[df["Tuition and fees"]>df["In-state"]]
print(x["State"].unique())
print(x["Tuition and fees"].max(),x["Tuition and fees"].min())
# Out:
# ['CA' 'VA' 'MI' 'GA' 'IL' 'WI' 'PA' 'OH' 'WA' 'IN' 'CT' 'MD' 'SC' 'NJ'
#  'MN' 'TX' 'MA' 'DE' 'CO' 'VT' 'AL' 'OR' 'TN' 'NH' 'KS' 'AZ' 'KY' 'RI'
#  'HI' 'ME' 'MO']
# $45,066  $18,332

# %%
df[df["Rank"]<100][["Name","City","Rank"]]
# Out:
#                                                   Name         City  Rank
# 0                                 Princeton University    Princeton     1
# 1                                   Harvard University    Cambridge     2
# 2                                University of Chicago      Chicago     3
# 3                                      Yale University    New Haven     3
# 4                                  Columbia University     New York     5
# ..                                                 ...          ...   ...
# 97                        Stony Brook University--SUNY  Stony Brook    96
# 98                                   Auburn University       Auburn    99
# 99                           Loyola University Chicago      Chicago    99
# 100  SUNY College of Environmental Science and Fore...     Syracuse    99
# 101                        University at Buffalo--SUNY      Buffalo    99
#
# [102 rows x 3 columns]

# %%
df[df["Undergrad Enrollment"] == df["Undergrad Enrollment"].min()][["Name","Undergrad Enrollment"]]
# Out:
#                                   Name Undergrad Enrollment
# 11  California Institute of Technology                1,001

# %%
df["Undergrad Enrollment"].str.replace(",","").apply(int).corr(df["Rank"].apply(int))
# Out:
# -0.04077093578774782
